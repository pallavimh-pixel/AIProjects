# %% [markdown]
# # Market Research Agent — RAG (FAISS) + Tavily Web Search
# * Build a FAISS-based retriever from CSV documents (company profiles & trend snippets).
# * Integrate a web search tool (Tavily) for fresh, external evidence.
# * Design a Planner → Coordinator → Tools → Draft → Reflect loop (single-agent).
# * Add JSON memory for traceability and citations.
# * Implement a simple evaluation harness and exercises for learners.

# %% [markdown]
# ## 1) Setup & Notes
# - This notebook includes cells that require internet (model downloads, Tavily).
# - If you do not have a `TAVILY_API_KEY`, the web search cell will show a safe offline stub.
# - The notebook stores two CSVs in `/mnt/data`: `company_profiles_rag_detailed.csv` and `market_trends_rag_detailed.csv`.
# - We use `sentence-transformers` (`all-MiniLM-L6-v2`) for embeddings and `faiss-cpu` for vector storage.

# %%
# (Run this cell to install packages if needed)
#%pip install faiss-cpu sentence-transformers tavily-python requests openai pandas
print('Install these packages if you run the notebook in a fresh environment: faiss-cpu, sentence-transformers, tavily-python, requests, openai, pandas')
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.12.0-cp311-cp311-macosx_13_0_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: sentence-transformers in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (5.1.2)
# Collecting tavily-python
#   Using cached tavily_python-0.7.12-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: requests in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (2.32.5)
# Requirement already satisfied: openai in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (1.109.1)
# Requirement already satisfied: pandas in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (2.3.3)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from faiss-cpu) (25.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (4.57.1)
# Requirement already satisfied: tqdm in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (2.2.2)
# Requirement already satisfied: scikit-learn in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (1.16.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (12.0.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.20.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.23)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.6.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: tiktoken>=0.5.1 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from tavily-python) (0.12.0)
# Requirement already satisfied: httpx in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from tavily-python) (0.28.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from requests) (2025.10.5)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from openai) (0.11.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from openai) (2.12.3)
# Requirement already satisfied: sniffio in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from openai) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpx->tavily-python) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from httpcore==1.*->httpx->tavily-python) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: sympy in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.5)
# Requirement already satisfied: jinja2 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/mommy/.pyenv/versions/3.11.13/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Downloading faiss_cpu-1.12.0-cp311-cp311-macosx_13_0_x86_64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 15.9 MB/s  0:00:00 eta 0:00:01
# Using cached tavily_python-0.7.12-py3-none-any.whl (15 kB)
# Installing collected packages: faiss-cpu, tavily-python
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [tavily-python]0m [tavily-python]
# Successfully installed faiss-cpu-1.12.0 tavily-python-0.7.12
# Note: you may need to restart the kernel to use updated packages.
# Install these packages if you run the notebook in a fresh environment: faiss-cpu, sentence-transformers, tavily-python, requests, openai, pandas

# %%
from dotenv import load_dotenv
import os
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY") or getpass.getpass("OpenAI API Key: ")
print(OPENAI_API_KEY)
TAVILY_API_KEY = os.getenv("TAVILY_API_KEY") or getpass.getpass("Tavily API Key: ")
print(TAVILY_API_KEY)
# Out:
# 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
# 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

# %% [markdown]
# ## 2) Load datasets (included two CSVs)
# *  add the csv files Path to .env

# %%
# After mounting, navigate to your file's path

import pandas as pd
# Read paths from .env
company_csv = os.getenv("COMPANY_CSV_PATH")
trend_csv = os.getenv("TREND_CSV_PATH")
print(company_csv)
print(trend_csv)
companies = pd.read_csv(company_csv)
trends = pd.read_csv(trend_csv)
print('Companies:')
display(companies.head(10))
print('\nTrends:')
display(trends.head(10))
# Out:
# /Users/pallavihegde/Documents/PythonProjects/IK/files/company_profiles_rag_detailed.csv
# /Users/pallavihegde/Documents/PythonProjects/IK/files/market_trends_rag_detailed.csv
# Companies:
#        CompanyName           Industry  Founded                      HQ  \
# 0         TechNova         AI & Cloud     2016      San Francisco, USA
# 1  MediCore Health      Healthcare AI     2012             Boston, USA
# 2         EcoDrive  Electric Vehicles     2018         Berlin, Germany
# 3          FinNest            FinTech     2014              London, UK
# 4        GreenGrid        ClimateTech     2019  Amsterdam, Netherlands
# 5         AgriNext           AgriTech     2020        Bangalore, India
# 6          EduWave             EdTech     2015         Toronto, Canada
# 7         BioSense      Healthcare AI     2017     Zurich, Switzerland
#
#    Employees                                        Description
# 0        250  Scalable AI cloud solutions, low-latency infer...
# 1       1200  Clinical decision support, diagnostic imaging ...
# 2        400  Subscription e-bikes and compact EVs optimized...
# 3        600  SMB-focused treasury, spend management and AI-...
# 4        180  Smart energy monitoring and optimization for c...
# 5        150  AI + IoT for precision farming, predictive irr...
# 6         90  Adaptive learning platform for higher educatio...
# 7        300  AI models for non-invasive diagnostics and rem...
# Trends:
#             Industry                                       Headline  \
# 0      Healthcare AI  AI diagnostic tools gain regulatory approvals
# 1         AI & Cloud            AI cloud adoption surges among SMEs
# 2  Electric Vehicles     Battery breakthroughs reduce charging time
# 3            FinTech               AI fraud detection lowers losses
# 4           AgriTech             Smart irrigation pilots save water
# 5             EdTech               Hybrid learning platforms expand
# 6        ClimateTech       Commercial buildings optimize energy use
#
#                                              Snippet        Date
# 0  Several imaging and diagnostic tools received ...  2024-11-10
# 1  Managed AI platforms report YoY growth ~40% as...  2024-10-05
# 2  Next-gen solid-state battery demos show 50% fa...  2024-09-21
# 3  Banks report ~30% reduction in fraud losses af...  2024-08-30
# 4  Pilot farms show 25-35% water savings using pr...  2024-07-14
# 5  Universities adopt hybrid models combining in-...  2024-06-02
# 6  AI-based controllers reduce peak consumption i...  2024-05-18

# %% [markdown]
# ### Quick EDA (Exploratory Data Analysis)
# We show simple counts and distributions to help learners understand the data shapes.

# %%
# Simple EDA
print('Companies by Industry:')
print(companies['Industry'].value_counts())
print('\nTrends by Industry:')
print(trends['Industry'].value_counts())
# Out:
# Companies by Industry:
# Industry
# Healthcare AI        2
# AI & Cloud           1
# Electric Vehicles    1
# FinTech              1
# ClimateTech          1
# AgriTech             1
# EdTech               1
# Name: count, dtype: int64
#
# Trends by Industry:
# Industry
# Healthcare AI        1
# AI & Cloud           1
# Electric Vehicles    1
# FinTech              1
# AgriTech             1
# EdTech               1
# ClimateTech          1
# Name: count, dtype: int64

# %% [markdown]
# ## 3) Build the RAG index (Embeddings + FAISS)
# **Why:** RAG lets the agent retrieve semantically relevant documents from local knowledge (CSV) instead of exact string matching.

# %%
#%pip install faiss-cpu

# %%
from sentence_transformers import SentenceTransformer
import faiss
import numpy as np

# Prepare docs
company_docs = companies.apply(lambda r: f"Company: {r['CompanyName']} | Industry: {r['Industry']} | Desc: {r['Description']}", axis=1).tolist()
trend_docs = trends.apply(lambda r: f"Industry: {r['Industry']} | Headline: {r['Headline']} | Snippet: {r['Snippet']} | Date: {r['Date']}", axis=1).tolist()
all_docs = company_docs + trend_docs
print(f"Preparing to embed {len(all_docs)} documents")

# Load model and create embeddings
model = SentenceTransformer('all-MiniLM-L6-v2')  # downloads once
embeddings = model.encode(all_docs, convert_to_numpy=True, show_progress_bar=True)

# Build FAISS index
dim = embeddings.shape[1]
index = faiss.IndexFlatL2(dim)
index.add(np.array(embeddings).astype('float32'))

# id->doc mapping
id2doc = {i: d for i, d in enumerate(all_docs)}

def rag_search(query, top_k=4):
    q_emb = model.encode([query], convert_to_numpy=True)
    D, I = index.search(np.array(q_emb).astype('float32'), top_k)
    return [id2doc[int(i)] for i in I[0]]
# Out:
# Preparing to embed 15 documents
# Batches: 100%|██████████| 1/1 [00:00<00:00, 27.24it/s]

# %% [markdown]
# ### Test RAG retrieval with example queries

# %%
print('RAG hits for "healthcare AI":')
for r in rag_search('healthcare AI', top_k=3):
    print('-', r[:300])
print('\nRAG hits for "precision farming":')
for r in rag_search('precision farming', top_k=3):
    print('-', r[:300])
# Out:
# RAG hits for "healthcare AI":
# - Industry: Healthcare AI | Headline: AI diagnostic tools gain regulatory approvals | Snippet: Several imaging and diagnostic tools received approval, leading to pilot deployments in regional hospitals. | Date: 2024-11-10
# - Company: MediCore Health | Industry: Healthcare AI | Desc: Clinical decision support, diagnostic imaging AI, and patient monitoring platforms used by hospitals.
# - Company: BioSense | Industry: Healthcare AI | Desc: AI models for non-invasive diagnostics and remote patient monitoring sensors.
#
# RAG hits for "precision farming":
# - Company: AgriNext | Industry: AgriTech | Desc: AI + IoT for precision farming, predictive irrigation, crop yield optimization.
# - Industry: AgriTech | Headline: Smart irrigation pilots save water | Snippet: Pilot farms show 25-35% water savings using predictive irrigation. | Date: 2024-07-14
# - Company: TechNova | Industry: AI & Cloud | Desc: Scalable AI cloud solutions, low-latency inference, enterprise workflows, developer SDKs, and model ops.

# %% [markdown]
# ## 4) Web Search Tool — Tavily
# **Why add web search?** RAG is limited to your local snapshots. Adding a web-search tool lets the agent fetch *fresh, time-sensitive* info (news, blog posts, regulatory updates).
#
# > Set `TAVILY_API_KEY` as an environment variable. If not set, a stub will be used so the notebook stays runnable offline.

# %%
import os, requests, time

TAVILY_API_KEY = os.getenv('TAVILY_API_KEY')
def web_search_tavily(query, num_results=3):
    if not TAVILY_API_KEY:
        # offline stub
        return [f"[stub] No TAVILY_API_KEY set. Would search for: {query}"]
    url = "https://api.tavily.com/search"
    headers = {"Content-Type":"application/json"}
    payload = {"api_key": TAVILY_API_KEY, "query": query, "num_results": num_results}
    resp = requests.post(url, json=payload, headers=headers, timeout=20)
    data = resp.json()
    results = []
    for r in data.get('results', []):
        title = r.get('title') or r.get('heading') or ''
        snippet = r.get('content') or r.get('snippet') or ''
        link = r.get('link') or r.get('url') or ''
        results.append({'title': title, 'snippet': snippet, 'link': link})
    return results

# %% [markdown]
# ### Test Tavily web search (will use stub if API key missing)

# %%
print(web_search_tavily('global AI healthcare market 2025', num_results=2))
# Out:
# [{'title': 'Artificial Intelligence in Healthcare Market: Surge by 2035', 'snippet': 'Global AI in healthcare market rising from USD 17.2B in 2025 to USD 77.2B in 2035, driven by diagnostics automation, smart hospitals,', 'link': 'https://orthospinenews.com/2025/11/07/artificial-intelligence-in-healthcare-market-to-surge-across-usa-europe-apac-and-saudi-arabia-by-2035/'}, {'title': 'AI in Healthcare Statistics: Comprehensive List for 2025', 'snippet': '* By **2030**, the global AI healthcare market is projected to soar to **$188 billion**, driven by a **37% CAGR**\xa0from **2022 to 2030**. * AI is expected to reduce healthcare costs by **$13 billion by 2025**. By **2030**, the **AI healthcare market in the USA** is predicted to generate **$102.2 billion**\xa0in revenue. By **2030**, the global AI healthcare market is set to soar to **$188 billion**, with a **CAGR of 37%**\xa0from **2022 to 2030**. By **2025**, the generative AI market in healthcare is expected to surpass **$2 billion**. Between **2025 and 2028**, the generative AI healthcare market is projected to grow by **146%**. Only **15%**\xa0of respondents believe AI would **exacerbate bias**\xa0in healthcare systems. Among those who perceive bias in healthcare, **51% believe AI** could play a key role in reducing that bias. **52% of respondents**\xa0believe that **AI-based skin cancer detection** represents a major advancement in healthcare.', 'link': 'https://www.dialoghealth.com/post/ai-healthcare-statistics'}, {'title': 'AI In Healthcare Market Size To Reach $505.59Bn By 2033', 'snippet': '# AI In Healthcare Market Size To Reach $505.59 Billion By 2033. ## **AI In Healthcare Market Growth & Trends**. The global\xa0AI in healthcare market size is expected to reach USD 505.59 billion by 2033, registering a CAGR of 38.81% from 2025 to 2033, according to a new report by Grand View Research, Inc. AI acts as a transformative force in healthcare systems, shifting them from reactive to proactive, predictive, and preventive models. Request a free sample copy or view report summary:\xa0AI In Healthcare Market Report. ## **AI In Healthcare Market Report Highlights**. * North America AI in healthcare market accounted for the largest revenue share of over 54% in 2024. ## **AI In Healthcare Market Segmentation**. Grand View Research has segmented the AI in healthcare market on the basis of on component, application, technology, end use, and region:. **AI In Healthcare\xa0Application Outlook (Revenue, USD Million, 2021 - 2033)**.', 'link': 'https://www.grandviewresearch.com/press-release/global-artificial-intelligence-healthcare-market'}, {'title': 'Artificial Intelligence in Healthcare Market Size to Hit USD 613.81 Bn ...', 'snippet': '*   [Our Services](https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market#). *   [Customised Research](https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market#). *   [About Us](https://www.precedenceresearch.com/artificial-intelligence-in-healthcare-market#). Artificial Intelligence in Healthcare Market (By Component: Hardware, Software Solutions, AI Solutions, Services; By Application Robot-assisted Surgery, Virtual Assistants, Administrative Workflow Assistants, Connected Medical Devices, Medical Imaging & Diagnostics, Clinical Trials, Fraud Detection, Cybersecurity, Dosage Error Reduction, Precision Medicine, Drug Discovery & Development, Lifestyle Management & Remote Patient Monitoring, Wearables, Others (Patient Engagement, etc.); By Technology: Machine Learning, Natural Language Processing, Context-aware Computing, Computer Vision; By End User: Healthcare Providers (Hospitals, Outpatient Facilities, and Others), Healthcare Payers, Healthcare Companies (Pharmaceutical, Biotechnology, Medical Devices), Patients, Government Agencies & Regulators, Others) - Global Industry Analysis, Size, Trends, Leading Companies, Regional Outlook, and Forecast 2025 to 2034. ![Image 14: AI in Healthcare Market Size ...

# %% [markdown]
# ## 5) Agent Design — Planner → Coordinator → Tools → Draft → Reflect
#
# We'll implement a single `MarketResearchAgent` class with:
# - `planner(query)` → creates an execution plan.
# - `gather(query)` → decides which tools to call (RAG and/or Tavily) and collects evidence.
# - `draft(evidence)` → calls an LLM (or Mock) to produce a draft brief.
# - `critique_and_revise(draft)` → reflection: critique the draft and revise it.
# - JSON memory for notes, drafts, and citations.

# %%
import os, json, time, re
from typing import List, Dict

memory_json = os.getenv("MEMORY_JSON")
# Minimal JSON memory
class JSONMemory:
    def __init__(self, path=memory_json):
        self.path = path
        if not os.path.exists(self.path):
            with open(self.path,'w') as f:
                json.dump({'notes':[], 'drafts':[], 'citations':[]}, f)
    def load(self):
        with open(self.path) as f:
            return json.load(f)
    def write(self, data):
        with open(self.path,'w') as f:
            json.dump(data, f, indent=2)
    def add_note(self, note):
        d = self.load(); d['notes'].append({'ts':time.time(), 'note':note}); self.write(d)
    def add_citation(self, src):
        d = self.load(); d['citations'].append(src); self.write(d)
    def add_draft(self, draft):
        d = self.load(); d['drafts'].append({'ts':time.time(),'draft':draft}); self.write(d)

# Mock LLM functions for offline use
class MockLLM:
    def draft(self, prompt):
        # create a short mock draft using heuristics
        return """Market Brief (mock)
- ICP: SMBs and mid-market
- Value Prop: Faster time-to-value
- Strengths: focused product, low TCO
- Risks: competition, pricing pressure
- Sources: [rag:0], [web:0]
"""
    def critique(self, draft):
        return "CRITIQUE: Add a metric and ensure at least one explicit citation. Clean up fluff."
    def revise(self, draft, critique):
        return draft + "\n\n[Revised: tightened bullets; added metric 20% YoY growth (example)]"

mock_llm = MockLLM()

class MarketResearchAgent:
    def __init__(self, memory:JSONMemory):
        self.memory = memory

    def planner(self, query:str)->List[str]:
        plan = ["Run RAG (internal docs)", "Run Tavily web search (freshness)", "Draft brief", "Critique & Revise"]
        self.memory.add_note('planner created')
        return plan

    def gather(self, query:str, top_k_rag=3, top_k_web=2, prefer_web=False)->List[Dict]:
        evidence = []
        rag_hits = rag_search(query, top_k=top_k_rag)
        for i,h in enumerate(rag_hits):
            evidence.append({'type':'rag', 'id':i, 'text':h})
            self.memory.add_citation(f'rag:{i}')
        web_hits = web_search_tavily(query, num_results=top_k_web)
        for i,h in enumerate(web_hits):
            evidence.append({
                'type':'web',
                'id':i,
                'text': h.get('snippet') if isinstance(h, dict) else str(h),
                'link': h.get('link') if isinstance(h, dict) else None
            })
            self.memory.add_citation(f'web:{i}')
        self.memory.add_note('gathered evidence')
        return evidence

    def draft(self, query:str, evidence:List[Dict])->str:
        # Build prompt
        context = '\n'.join([f"[{e['type']}:{e['id']}] {e['text']}" for e in evidence])
        prompt = f"Draft a concise market brief for: {query}\nUse the evidence below:\n{context}\nKeep it 4-8 bullets and include citations."
        # Call LLM (mock or real)
        draft = mock_llm.draft(prompt)
        self.memory.add_draft(draft)
        return draft

    def critique_and_revise(self, draft:str)->str:
        critique = mock_llm.critique(draft)
        revised = mock_llm.revise(draft, critique)
        self.memory.add_draft(revised)
        return revised

# %% [markdown]
# ### 6) Example end-to-end run (Planner → Gather → Draft → Revise) — run this cell to see outputs step-by-step

# %%
# Make sure memory directory exists before using JSONMemory
import os
load_dotenv()
memory_path = os.getenv("MEMORY_JSON_PATH")
os.makedirs(memory_path, exist_ok=True)

# Initialize memory + agent
#mem = JSONMemory(path="/Users/pallavihegde/Documents/PythonProjects/IK/files/agent_memory_rag_tavily.json")

# Read from .env with a default fallback
mem_json = os.getenv("MEMORY_JSON")

mem = JSONMemory(path=mem_json)

agent = MarketResearchAgent(mem)

# Run workflow
query = 'Healthcare AI market outlook 2025'
print('Plan:')
print(agent.planner(query))

evidence = agent.gather(query, top_k_rag=3, top_k_web=2)
print('\nCollected Evidence (first 400 chars each):')
for e in evidence:
    txt = e['text'] if isinstance(e['text'], str) else str(e['text'])
    print('-', e['type'], e.get('id'), ':', txt[:400])

draft = agent.draft(query, evidence)
print('\nDraft:\n', draft)

final = agent.critique_and_revise(draft)
print('\nFinal Revised Draft:\n', final)

print('\nMemory snapshot:')
print(mem.load())
# Out:
# Plan:
# ['Run RAG (internal docs)', 'Run Tavily web search (freshness)', 'Draft brief', 'Critique & Revise']
#
# Collected Evidence (first 400 chars each):
# - rag 0 : Industry: Healthcare AI | Headline: AI diagnostic tools gain regulatory approvals | Snippet: Several imaging and diagnostic tools received approval, leading to pilot deployments in regional hospitals. | Date: 2024-11-10
# - rag 1 : Company: MediCore Health | Industry: Healthcare AI | Desc: Clinical decision support, diagnostic imaging AI, and patient monitoring platforms used by hospitals.
# - rag 2 : Industry: AI & Cloud | Headline: AI cloud adoption surges among SMEs | Snippet: Managed AI platforms report YoY growth ~40% as SMEs outsource model infra. | Date: 2024-10-05
# - web 0 : Recent market analysis shows the global healthcare AI market is expected to grow from $26.6 billion in 2024 to approximately $187.7 billion in
# - web 1 : # AI in healthcare statistics 2025. AI in healthcare market overview. ## AI in healthcare market overview. ### AI in healthcare adoption rates. The share of healthcare organizations that have adopted or explored generative AI rose from 72% in Q1 2024 to 85% by the end of the year. How healthcare organizations approach AI development. In 2024, most healthcare organizations leaned on partnerships to
# - web 2 : It is further informed by conversations with dozens of additional industry stakeholders.9 The report offers a detailed look at healthcare’s AI transformation, exploring where organizations are advancing from pilots to production, which business models are converting services into software, and where the next wave of category leaders is poised to emerge across care delivery, health insurance, and d
# - web 3 : For many healthcare organizations, AI is still a buzz phrase, but one that is attractive due to its promise to improve clinical and administrative workflows. In 2025, we expect healthcare organizations to have more risk tolerance for AI initiatives, which will lead to increased adoption. Here are some of the ways healthcare organizations are likely to approach AI in 2025. ## Which AI Solutions Wil
# - web 4 : # Healthcare. ###### Letter from our healthcare industry lead. In our 2024 outlook for the healthcare industry, Slalom shared our profound optimism in the path toward person-centered care. Our 2025 outlook focuses on pragmatic opportunities to address barriers in our healthcare system—realistic solutions that can improve access to care, reduce burdens on the healthcare workforce, and create a more
#
# Draft:
#  Market Brief (mock)
# - ICP: SMBs and mid-market
# - Value Prop: Faster time-to-value
# - Strengths: focused product, low TCO
# - Risks: competition, pricing pressure
# - Sources: [rag:0], [web:0]
#
#
# Final Revised Draft:
#  Market Brief (mock)
# - ICP: SMBs and mid-market
# - Value Prop: Faster time-to-value
# - Strengths: focused product, low TCO
# - Risks: competition, pricing pressure
# - Sources: [rag:0], [web:0]
#
#
# [Revised: tightened bullets; added metric 20% YoY growth (example)]
#
# Memory snapshot:
# {'notes': [{'ts': 1762470075.992542, 'note': 'planner created'}, {'ts': 1762470077.458019, 'note': 'gathered evidence'}, {'ts': 1768964227.464061, 'note': 'planner created'}, {'ts': 1768964230.150781, 'note': 'gathered evidence'}, {'ts': 1769030613.880832, 'note': 'planner created'}, {'ts': 1769030616.412648, 'note': 'gathered evidence'}, {'ts': 1769030616.500845, 'note': 'planner created'}, {'ts': 1769030616.962463, 'note': 'gathered evidence'}, {'ts': 1769037542.287134, 'note': 'planner created'}, {'ts': 1769037544.941303, 'note': 'gathered evidence'}], 'drafts': [{'ts': 1762470077.4599879, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n'}, {'ts': 1762470077.461791, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n\n\n[Revised: tightened bullets; added metric 20% YoY growth (example)]'}, {'ts': 1768964230.152103, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n'}, {'ts': 1768964230.152874, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n\n\n[Revised: tightened bullets; added metric 20% YoY growth (example)]'}, {'ts': 1769030616.4135292, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n'}, {'ts': 1769030616.4139829, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n\n\n[Revised: tightened bullets; added metric 20% YoY growth (example)]'}, {'ts': 1769030616.964145, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n'}, {'ts': 1769030616.966672, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n\n\n[Revised: tightened bullets; added metric 20% YoY growth (example)]'}, {'ts': 1769037544.9424121, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n'}, {'ts': 1769037544.944888, 'draft': 'Market Brief (mock)\n- ICP: SMBs and mid-market\n- Value Prop: Faster time-to-value\n- Strengths: focused product, low TCO\n- Risks: competition, pricing pressure\n- Sources: [rag:0], [web:0]\n\n\n[Revised: tightened bullets; added metric 20% YoY growth (example)]'}], 'citations': ['rag:0', 'rag:1', 'rag:2', 'web:0', 'web:1', 'web:2', 'web:3', 'web:4', 'rag:0', 'rag:1', 'rag:2', 'web:0', 'web:1', 'web:2', 'web:3', 'web:4', 'rag:0', 'rag:1', 'rag:2', 'web:0', 'web:1', 'web:2', 'web:3', 'web:4', 'rag:0', 'rag:1', 'rag:2', 'web:0', 'web:1', 'web:2', 'web:3', 'web:4', 'rag:0', 'rag:1', 'rag:2', 'web:0', 'web:1', 'web:2', 'web:3', 'web:4']}

# %% [markdown]
# ## 7) Evaluation harness
# Implement a small evaluator that checks:
# - Relevance (on-topic), Evidence (citations present), Specificity (numbers or years), Clarity (bullets), Freshness (web evidence)

# %%
import re, json
# Read from .env with a default fallback
mem_json = os.getenv("MEMORY_JSON")
def evaluate(text:str, memory_json_path=mem_json):
    scores = {}
    scores['Relevance'] = 1 if 'health' in text.lower() or 'healthcare' in text.lower() else 0
    with open(memory_json_path) as f: mem = json.load(f)
    scores['Evidence'] = 1 if len(mem.get('citations',[]))>0 else 0
    scores['Specificity'] = 1 if re.search(r'\d{4}|\d+%', text) else 0
    scores['Clarity'] = 1 if '-' in text else 0
    scores['Freshness'] = 1 if any(c.startswith('web:') for c in mem.get('citations',[])) else 0
    return scores

print('Eval example (from final draft):')
# if final exists in the notebook run sequence, you can call evaluate(final)
# Here we just show the function
print('Call evaluate(final_draft) after running the agent cells to get scores')
# Out:
# Eval example (from final draft):
# Call evaluate(final_draft) after running the agent cells to get scores

# %% [markdown]
# ## 8) Extension Plan (work in progress)
# - Replace `MockLLM` with OpenAI or another LLM (ensure to secure API keys).
# - Add caching for rag_search results and incremental index updates.
# - Build a "Researcher" agent that runs web searches in parallel and a "Writer" agent that drafts.
# - Add a Streamlit app to query the agent interactively.
# - Add guardrails: schema validation for drafts (pydantic) and rejection rules if no citations.
